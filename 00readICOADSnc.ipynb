# %%
import xarray as xr

path = "data/cldc.sextile3.nc"
ds = xr.open_dataset(path)
ds
# Out:
# <xarray.Dataset> Size: 175MB
# Dimensions:  (lat: 90, lon: 180, time: 2706)
# Coordinates:
#   * lat      (lat) float32 360B 89.0 87.0 85.0 83.0 ... -83.0 -85.0 -87.0 -89.0
#   * lon      (lon) float32 720B 1.0 3.0 5.0 7.0 9.0 ... 353.0 355.0 357.0 359.0
#   * time     (time) datetime64[ns] 22kB 1800-01-01 1800-02-01 ... 2025-06-01
# Data variables:
#     cldc     (time, lat, lon) float32 175MB ...
# Attributes:
#     title:          ICOADS 2-degree Enhanced
#     history:        Release 3.0.0 (1800-2014); Release 3.0.2 (2015-present)
#     Conventions:    CF-1.6
#     references:     https://www.psl.noaa.gov/data/gridded/data.coads.2deg.html
#     dataset_title:  International Comprehensive Ocean-Atmosphere Data Set (IC...
#     website:        icoads.noaa.gov
#     doi:            doi:                                                     ...
#     source:         NOAA National Centers for Environmental Information (NCEI)
# ...

# %%
cloudy1Day= ds.cldc[1500]
cloudy1Day
# Out:
# <xarray.DataArray 'cldc' (lat: 90, lon: 180)> Size: 65kB
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 360B 89.0 87.0 85.0 83.0 ... -83.0 -85.0 -87.0 -89.0
#   * lon      (lon) float32 720B 1.0 3.0 5.0 7.0 9.0 ... 353.0 355.0 357.0 359.0
#     time     datetime64[ns] 8B 1925-01-01
# Attributes:
#     unpacked_valid_range:  [0. 8.]
#     actual_range:          [0. 8.]
#     units:                 okta
#     precision:             1
#     long_name:             Cloudiness Monthly 3rd Sextile at Surface
#     dataset:               ICOADS 2-degree Enhanced
#     var_desc:              Cloudiness
#     level_desc:            Surface
#     statistic:             Third Sextile (Median)
# ...

# %%
cloudy1Day.plot()

# %%
cloudy1Day.max()
# Out:
# <xarray.DataArray 'cldc' ()> Size: 4B
# array(8., dtype=float32)
# Coordinates:
#     time     datetime64[ns] 8B 1925-01-01

# %%
cloudy1Day.min()
# Out:
# <xarray.DataArray 'cldc' ()> Size: 4B
# array(0., dtype=float32)
# Coordinates:
#     time     datetime64[ns] 8B 1925-01-01
